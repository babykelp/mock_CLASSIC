# %%
import xarray as xr
import mock_scr as ms

# %% [markdown]
# Дано: init_file для участка альпийского луга не подверженного выпасу.
# Задание: открыть инициализационный файл и найти в нем параметры растительности.

# %%
soil_temp = ms.mock_class(init_file)
soil_temp
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:  (lon: 1, lat: 1, layer: 8, time: 36)
# Coordinates:
#   * lon      (lon) float64 8B 100.2
#   * lat      (lat) float64 8B 37.25
#   * layer    (layer) int16 16B 1 2 3 4 5 6 7 8
#   * time     (time) object 288B 2019-01-31 00:00:00 ... 2021-12-31 00:00:00
# Data variables:
#     tsl      (time, layer, lat, lon) float64 2kB ...
# Attributes:
#     title:        CLASSIC output file
#     timestamp:    20250107 1732
#     Conventions:  COARDS
#     node_offset:  1
#     Comment:       test

# %% [markdown]
# Задание 2: поменяйте параметры растительности, запустите модель заново -- сравните
